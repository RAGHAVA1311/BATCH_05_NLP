# %% [markdown]
# <a href="https://colab.research.google.com/github/RAGHAVA1311/BATCH_05_NLP/blob/main/Nlp_assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Example text data
text = """Once upon a time, there was a little girl named Red Riding Hood.
      She loved to visit her grandmother, who lived in the woods.
      One day, her mother asked her to take a basket of goodies to her grandmother.
      On her way through the woods, she met a big bad wolf who wanted to eat her."""

# Tokenization and preparing sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for i in range(1, len(tokenizer.texts_to_sequences([text])[0])):
    n_gram_sequence = tokenizer.texts_to_sequences([text])[0][:i+1]
    input_sequences.append(n_gram_sequence)

# Pad sequences
max_seq_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))

# Inputs and labels
X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# Define Transformer-based model using MultiHeadAttention
def transformer_block(vocab_size, seq_len):
    inputs = tf.keras.layers.Input(shape=(seq_len,))
    embedding = tf.keras.layers.Embedding(vocab_size, 64)(inputs)

    # Multi-Head Attention Layer
    attention_output = tf.keras.layers.MultiHeadAttention(num_heads=2, key_dim=64)(embedding, embedding)
    attention_output = tf.keras.layers.LayerNormalization()(attention_output + embedding)

    # Feed-forward network
    ff_output = tf.keras.layers.Dense(128, activation='relu')(attention_output)
    ff_output = tf.keras.layers.Dense(64)(ff_output)
    ff_output = tf.keras.layers.LayerNormalization()(ff_output + attention_output)

    outputs = tf.keras.layers.GlobalAveragePooling1D()(ff_output)
    outputs = tf.keras.layers.Dense(vocab_size, activation='softmax')(outputs)

    model = tf.keras.models.Model(inputs, outputs)
    return model

# Build model
model = transformer_block(total_words, max_seq_len-1)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model (20, 60, 70 epochs)
epochs_list = [20, 60, 70]
history = []
for epoch in epochs_list:
    print(f"Training with {epoch} epochs...")
    h = model.fit(X, y, epochs=epoch, verbose=1)
    history.append(h)

# Text generation using seed text
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=1)
        output_word = tokenizer.index_word[predicted_word_index[0]]
        seed_text += " " + output_word
    return seed_text

seed_text = "Once upon a time"
generated_text = generate_text(seed_text, 50, model, max_seq_len)
print("Generated text:", generated_text)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 55)]                 0         []
#
#  embedding_1 (Embedding)     (None, 55, 64)               2624      ['input_2[0][0]']
#
#  multi_head_attention_1 (Mu  (None, 55, 64)               33216     ['embedding_1[0][0]',
#  ltiHeadAttention)                                                   'embedding_1[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 55, 64)               0         ['multi_head_attention_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'embedding_1[0][0]']
#
#  layer_normalization_2 (Lay  (None, 55, 64)               128       ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  dense_3 (Dense)             (None, 55, 128)              8320      ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dense_4 (Dense)             (None, 55, 64)               8256      ['dense_3[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 55, 64)               0         ['dense_4[0][0]',
#  OpLambda)                                                           'layer_normalization_2[0][0]'
#                                                                     ]
#
#  layer_normalization_3 (Lay  (None, 55, 64)               128       ['tf.__operators__.add_3[0][0]
#  erNormalization)                                                   ']
#
#  global_average_pooling1d_1  (None, 64)                   0         ['layer_normalization_3[0][0]'
#   (GlobalAveragePooling1D)                                          ]
#
#  dense_5 (Dense)             (None, 41)                   2665      ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 55337 (216.16 KB)
# Trainable params: 55337 (216.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Training with 20 epochs...
# Epoch 1/20
# 2/2 [==============================] - 2s 26ms/step - loss: 4.1402 - accuracy: 0.0182
# Epoch 2/20
# 2/2 [==============================] - 0s 24ms/step - loss: 3.7190 - accuracy: 0.0545
# Epoch 3/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.5954 - accuracy: 0.1273
# Epoch 4/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.5161 - accuracy: 0.1455
# Epoch 5/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4793 - accuracy: 0.1091
# Epoch 6/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4346 - accuracy: 0.1091
# Epoch 7/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.3908 - accuracy: 0.1273
# Epoch 8/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3633 - accuracy: 0.1273
# Epoch 9/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.3383 - accuracy: 0.1273
# Epoch 10/20
# 2/2 [==============================] - 0s 20ms/step - loss: 3.3148 - accuracy: 0.1091
# Epoch 11/20
# 2/2 [==============================] - 0s 20ms/step - loss: 3.2863 - accuracy: 0.1091
# Epoch 12/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.2690 - accuracy: 0.1273
# Epoch 13/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.2453 - accuracy: 0.1455
# Epoch 14/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.2265 - accuracy: 0.1455
# Epoch 15/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.2042 - accuracy: 0.1455
# Epoch 16/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1814 - accuracy: 0.1455
# Epoch 17/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1633 - accuracy: 0.1455
# Epoch 18/20
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1496 - accuracy: 0.1455
# Epoch 19/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1313 - accuracy: 0.1273
# Epoch 20/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.1076 - accuracy: 0.1455
# Training with 60 epochs...
# Epoch 1/60
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0927 - accuracy: 0.1273
# Epoch 2/60
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0786 - accuracy: 0.1455
# Epoch 3/60
# 2/2 [==============================] - 0s 20ms/step - loss: 3.0594 - accuracy: 0.1273
# Epoch 4/60
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0506 - accuracy: 0.1455
# Epoch 5/60
# 2/2 [==============================] - 0s 21ms/step - loss: 3.0311 - accuracy: 0.1273
# Epoch 6/60
# 2/2 [==============================] - 0s 21ms/step - loss: 3.0118 - accuracy: 0.1273
# Epoch 7/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.9985 - accuracy: 0.1455
# Epoch 8/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.9779 - accuracy: 0.1273
# Epoch 9/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.9653 - accuracy: 0.1273
# Epoch 10/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9552 - accuracy: 0.1273
# Epoch 11/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9393 - accuracy: 0.1455
# Epoch 12/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.9244 - accuracy: 0.1455
# Epoch 13/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9078 - accuracy: 0.1455
# Epoch 14/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.8943 - accuracy: 0.1455
# Epoch 15/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8833 - accuracy: 0.1273
# Epoch 16/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.8650 - accuracy: 0.1455
# Epoch 17/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.8497 - accuracy: 0.1455
# Epoch 18/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8370 - accuracy: 0.1455
# Epoch 19/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.8178 - accuracy: 0.1455
# Epoch 20/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8094 - accuracy: 0.1636
# Epoch 21/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7936 - accuracy: 0.1273
# Epoch 22/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7817 - accuracy: 0.1455
# Epoch 23/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7692 - accuracy: 0.1455
# Epoch 24/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7502 - accuracy: 0.1636
# Epoch 25/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.7321 - accuracy: 0.1636
# Epoch 26/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7261 - accuracy: 0.1273
# Epoch 27/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.7039 - accuracy: 0.1455
# Epoch 28/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.6900 - accuracy: 0.1636
# Epoch 29/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.6802 - accuracy: 0.1636
# Epoch 30/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6689 - accuracy: 0.1636
# Epoch 31/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.6492 - accuracy: 0.1636
# Epoch 32/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.6376 - accuracy: 0.2000
# Epoch 33/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.6283 - accuracy: 0.1636
# Epoch 34/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.6320 - accuracy: 0.1455
# Epoch 35/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.6078 - accuracy: 0.1455
# Epoch 36/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.5848 - accuracy: 0.1818
# Epoch 37/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.5776 - accuracy: 0.1636
# Epoch 38/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5683 - accuracy: 0.2182
# Epoch 39/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.5486 - accuracy: 0.1818
# Epoch 40/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.5393 - accuracy: 0.2182
# Epoch 41/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5226 - accuracy: 0.1818
# Epoch 42/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.5161 - accuracy: 0.1818
# Epoch 43/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4984 - accuracy: 0.2000
# Epoch 44/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4841 - accuracy: 0.2000
# Epoch 45/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.4606 - accuracy: 0.2000
# Epoch 46/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4580 - accuracy: 0.2000
# Epoch 47/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4394 - accuracy: 0.2000
# Epoch 48/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.4301 - accuracy: 0.2000
# Epoch 49/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4132 - accuracy: 0.2000
# Epoch 50/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.3798 - accuracy: 0.2727
# Epoch 51/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.3765 - accuracy: 0.1636
# Epoch 52/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.3655 - accuracy: 0.2182
# Epoch 53/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.3532 - accuracy: 0.2000
# Epoch 54/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.3312 - accuracy: 0.2182
# Epoch 55/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.3339 - accuracy: 0.2182
# Epoch 56/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2938 - accuracy: 0.2545
# Epoch 57/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.2986 - accuracy: 0.2727
# Epoch 58/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2898 - accuracy: 0.2182
# Epoch 59/60
# 2/2 [==============================] - 0s 19ms/step - loss: 2.2640 - accuracy: 0.2364
# Epoch 60/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2403 - accuracy: 0.1818
# Training with 70 epochs...
# Epoch 1/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1861 - accuracy: 0.3091
# Epoch 2/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2159 - accuracy: 0.3091
# Epoch 3/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2115 - accuracy: 0.2727
# Epoch 4/70
# 2/2 [==============================] - 0s 19ms/step - loss: 2.1717 - accuracy: 0.2727
# Epoch 5/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1381 - accuracy: 0.2545
# Epoch 6/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1348 - accuracy: 0.2182
# Epoch 7/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1233 - accuracy: 0.2364
# Epoch 8/70
# 2/2 [==============================] - 0s 19ms/step - loss: 2.0980 - accuracy: 0.3455
# Epoch 9/70
# 2/2 [==============================] - 0s 19ms/step - loss: 2.0657 - accuracy: 0.3636
# Epoch 10/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.0443 - accuracy: 0.3636
# Epoch 11/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0362 - accuracy: 0.3273
# Epoch 12/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.0073 - accuracy: 0.3273
# Epoch 13/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0075 - accuracy: 0.4545
# Epoch 14/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.9666 - accuracy: 0.4000
# Epoch 15/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.9628 - accuracy: 0.3455
# Epoch 16/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.9306 - accuracy: 0.4545
# Epoch 17/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.8848 - accuracy: 0.4545
# Epoch 18/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.9344 - accuracy: 0.3818
# Epoch 19/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.8829 - accuracy: 0.3636
# Epoch 20/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.8467 - accuracy: 0.3636
# Epoch 21/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.8590 - accuracy: 0.3818
# Epoch 22/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8261 - accuracy: 0.4000
# Epoch 23/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.8632 - accuracy: 0.4909
# Epoch 24/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.8330 - accuracy: 0.3818
# Epoch 25/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.8073 - accuracy: 0.4364
# Epoch 26/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.7612 - accuracy: 0.4909
# Epoch 27/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.7550 - accuracy: 0.3818
# Epoch 28/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.7385 - accuracy: 0.4727
# Epoch 29/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.7168 - accuracy: 0.4909
# Epoch 30/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.6998 - accuracy: 0.5455
# Epoch 31/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.7114 - accuracy: 0.4000
# Epoch 32/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6805 - accuracy: 0.5818
# Epoch 33/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6806 - accuracy: 0.5818
# Epoch 34/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6403 - accuracy: 0.4909
# Epoch 35/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6187 - accuracy: 0.6000
# Epoch 36/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6357 - accuracy: 0.4000
# Epoch 37/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6070 - accuracy: 0.5455
# Epoch 38/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5803 - accuracy: 0.4727
# Epoch 39/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.5876 - accuracy: 0.4727
# Epoch 40/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.5738 - accuracy: 0.4909
# Epoch 41/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5613 - accuracy: 0.5091
# Epoch 42/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5202 - accuracy: 0.6000
# Epoch 43/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5089 - accuracy: 0.5818
# Epoch 44/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5247 - accuracy: 0.5636
# Epoch 45/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.5069 - accuracy: 0.5636
# Epoch 46/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4700 - accuracy: 0.6364
# Epoch 47/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.4894 - accuracy: 0.6545
# Epoch 48/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.5189 - accuracy: 0.4364
# Epoch 49/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.4748 - accuracy: 0.5818
# Epoch 50/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4509 - accuracy: 0.5455
# Epoch 51/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4233 - accuracy: 0.5636
# Epoch 52/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.4625 - accuracy: 0.5455
# Epoch 53/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.4499 - accuracy: 0.4909
# Epoch 54/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3956 - accuracy: 0.6000
# Epoch 55/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3626 - accuracy: 0.6000
# Epoch 56/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3940 - accuracy: 0.5455
# Epoch 57/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3371 - accuracy: 0.6364
# Epoch 58/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3275 - accuracy: 0.6727
# Epoch 59/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2919 - accuracy: 0.6909
# Epoch 60/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2865 - accuracy: 0.7091
# Epoch 61/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2491 - accuracy: 0.7091
# Epoch 62/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2347 - accuracy: 0.7455
# Epoch 63/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.2362 - accuracy: 0.7636
# Epoch 64/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2268 - accuracy: 0.7636
# Epoch 65/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1991 - accuracy: 0.7273
# Epoch 66/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.2037 - accuracy: 0.7091
# Epoch 67/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1843 - accuracy: 0.7636
# Epoch 68/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1849 - accuracy: 0.7091
# Epoch 69/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1485 - accuracy: 0.7818
# Epoch 70/70
# 2/2 [==============================] - 0s 19ms/step - loss: 1.1532 - accuracy: 0.7273
# Generated text: Once upon a time a was little little girl red riding hood she loved to visit her grandmother who lived in the woods one day her mother asked to her take a basket basket of goodies her her her on her grandmother way the the woods she a big her bad who her wolf
